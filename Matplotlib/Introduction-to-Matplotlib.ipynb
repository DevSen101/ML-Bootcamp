# %% [markdown]
# # Matplotlib
# - Matplotlib is a python data visualization library can create basic or advance plots (figures). which help us to visualize our data by converting numerical data into plot and visuals.
# - Built on NumPy arrays (and Python)
# - Integrates directly with pandas
# - Simple to use interface(Once we get the foundation)

# %% [markdown]
# ### Importing matplotlib, numpy and pandas

# %%
# import matplotlib
# %matplotlib inline 
import matplotlib.pyplot as plt
# import numpy
import numpy as np
# import pandas
import pandas as pd

# %% [markdown]
# ## Simple way to create plots.
# ### plot()
# - Plot y versus x as lines and/or markers.

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %% [markdown]
# ### show()
# - Display all open figures.

# %%
plt.plot()
plt.show()
# will do same exact thing.

# %%
plt.plot([1,2,3,4]);

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y);

# %% [markdown]
# ## First Method
# ### figure()
# - Create a new figure, or activate an existing figure.
# ### add_subplot()
# - Add an axes to the figure as part of a subplot arrangement.

# %%
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %% [markdown]
# ## Second Method
#
# ### add_axes()
# - Add an axes to the figure.
# ### plot()
# - Add some data
# - Plot y versus x as lines and/or markers.

# %%
fig = plt.figure()
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y)
plt.show()

# %% [markdown]
# ## Third Method (Recommended)
# ### subplots()
# - Create a figure and a set of subplots.
# - This utility wrapper makes it convenient to create common layouts of subplots, including the enclosing figure object, in a single call.

# %%
fig, ax = plt.subplots()
ax.plot(x, y); # add some data

# %% [markdown]
# -------------------------------------------------------------------------------------

# %% [markdown]
# <img src="assets/matplotlib-anatomy-of-a-plot.png">

# %% [markdown]
# ## Matplotlib Example Workflow

# %%
# Step -0 Import matplotlib and get it ready for plotting in jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# Step -1 Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# Step -2 Setup plot
fig, ax = plt.subplots(figsize=(10, 10)) #(width, height)

# Step -3 Plot data
ax.plot(x, y)

# Step -4 Customize plot
ax.set(title="Sample Plot",
      xlabel="x-axis",
      ylabel="y-axis")

# Step -5 Save & Show (you save the whole figure)
fig.savefig("images/sample-plot.png")

# %% [markdown]
# ## Making figures with NumPy Arrays
#
# ### We want :-
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplots

# %%
import numpy as np

# %% [markdown]
# ### linspace()
# - Return evenly spaced numbers over a specified interval.

# %%
# Create some data
x = np.linspace(0, 10, 100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %% [markdown]
# ## Line Plot

# %%
#  Plot the data and create the line plot.
fix, ax = plt.subplots()
ax.plot(x, x**2);

# %% [markdown]
# ----------------------------------

# %% [markdown]
# ## Scatter Plot
#
# ### scatter()
# - A scatter plot of *y* vs. *x* with varying marker size and/or color.

# %%
# Use same data to make scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
# Another scatter plot
fix, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %% [markdown]
# ----------------------------------------------------

# %% [markdown]
# ## Bar Plot

# %% [markdown]
# ### bar()
# - Make a bar plot.

# %%
nut_butter_prices = {"Almond Butter": 10,
                     "Peanut Butter": 8,
                     "Cashew Butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Nut Butter Store",
       xlabel="Items", ylabel="Price ($)");

# %% [markdown]
# ### Same data with Horizontal representation.
#
# ### barh()
# - Make a horizontal bar plot.

# %%
fix, ax = plt.subplots()
ax.barh(nut_butter_prices.keys(), nut_butter_prices.values());

# %% [markdown]
# ------------------------------------------

# %% [markdown]
# ## Histogram
#
# ### random()
# - Random Number Generation
# ### randn()
# - Return a sample (or samples) from the "standard normal" distribution.
# ### hist()
# - Compute and plot a histogram.

# %%
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# -------------------------------------------------------------------
# ## Want to show different plots in once.
# <img src="assets/matplotlib-anatomy-of-a-plot-with-code.png">
#
# ### Subplots Option 1

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                           ncols=2,
                                           figsize=(10,15))
# Plot to each different axis
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %% [markdown]
# ### Subplots Option 2

# %%
fig, ax = plt.subplots(2,2, figsize=(10,15))
# Plot to each different index
ax[0,0].plot(x, x/2);
ax[0,1].scatter(np.random.random(10), np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from pandas DataFrames

# %%
import pandas as pd

# %%
# Make a DataFrame
car_sales = pd.read_csv("data/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ### cumsum()
# - Return cumulative sum over a DataFrame or Series axis.
# - Returns a DataFrame or Series of the same size containing the cumulative
# sum.
#
# ### date_range()
# - Return a fixed frequency DatetimeIndex.

# %%
In [3]: np.random.seed(123456)

In [4]: ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2026", periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ### astype()
# - Convert a string or number to a floating-point number, if possible.

# %%
car_sales["Price"] = (car_sales["Price"].str.replace(r"[$,]", "", regex=True).astype(float).astype(int))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2026", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2026-01-01
# 1   Honda    Red          87899      4   5000 2026-01-02
# 2  Toyota   Blue          32549      3   7000 2026-01-03
# 3     BMW  Black          11179      5  22000 2026-01-04
# 4  Nissan  White         213095      4   3500 2026-01-05
# 5  Toyota  Green          99213      4   4500 2026-01-06
# 6   Honda   Blue          45698      4   7500 2026-01-07
# 7   Honda   Blue          54738      4   7000 2026-01-08
# 8  Toyota  White          60000      4   6250 2026-01-09
# 9  Nissan  White          31600      4   9700 2026-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2026-01-01         4000
# 1   Honda    Red          87899      4   5000 2026-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2026-01-03        16000
# 3     BMW  Black          11179      5  22000 2026-01-04        38000
# 4  Nissan  White         213095      4   3500 2026-01-05        41500
# 5  Toyota  Green          99213      4   4500 2026-01-06        46000
# 6   Honda   Blue          45698      4   7500 2026-01-07        53500
# 7   Honda   Blue          54738      4   7000 2026-01-08        60500
# 8  Toyota  White          60000      4   6250 2026-01-09        66750
# 9  Nissan  White          31600      4   9700 2026-01-10        76450

# %% [markdown]
# ###  Let's Plot The Total Sales

# %%
car_sales.plot();

# %%
car_sales.plot(x="Sale Date", y="Total Sales")
# Out:
# <Axes: xlabel='Sale Date'>

# %% [markdown]
# ### Scatter Plot

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter")
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %% [markdown]
# --------------------------------------

# %% [markdown]
# ### Bar Graph

# %%
x = np.random.rand(10, 4) # rand - return random array of given shape.
x
# Turn it to a DataFrame
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.365956  0.024949  0.240687  0.012899
# 1  0.746317  0.176577  0.039863  0.106379
# 2  0.116694  0.050626  0.839019  0.298509
# 3  0.307938  0.689462  0.181594  0.326069
# 4  0.441359  0.769168  0.501312  0.037995
# 5  0.689450  0.984570  0.889612  0.530526
# 6  0.562271  0.277608  0.022471  0.279898
# 7  0.776647  0.068914  0.811207  0.063474
# 8  0.766179  0.193433  0.873315  0.437170
# 9  0.672644  0.604968  0.402883  0.309529

# %% [markdown]
# ###  One way to make bar graph

# %%
df.plot.bar();

# %% [markdown]
# ### Another way to make bar graph

# %%
df.plot(kind="bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2026-01-01         4000
# 1   Honda    Red          87899      4   5000 2026-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2026-01-03        16000
# 3     BMW  Black          11179      5  22000 2026-01-04        38000
# 4  Nissan  White         213095      4   3500 2026-01-05        41500
# 5  Toyota  Green          99213      4   4500 2026-01-06        46000
# 6   Honda   Blue          45698      4   7500 2026-01-07        53500
# 7   Honda   Blue          54738      4   7000 2026-01-08        60500
# 8  Toyota  White          60000      4   6250 2026-01-09        66750
# 9  Nissan  White          31600      4   9700 2026-01-10        76450

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar")
# Out:
# <Axes: xlabel='Make'>

# %% [markdown]
# ------------------------------------------------------------------------------

# %% [markdown]
# ### Histogram

# %%
car_sales["Odometer (KM)"].plot.hist();

# %% [markdown]
# ### Another way to make Histogram

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
# bins parameter - no of bins use in Histogram.
car_sales["Odometer (KM)"].plot.hist(bins=100);

# %% [markdown]
# ### Let's work on Another DataSet.

# %%
heart_desease = pd.read_csv("data/heart-disease.csv")
heart_desease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#  Create a Histogram of age.
heart_desease["age"].plot.hist(bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
heart_desease.plot.hist(figsize=(10, 30), subplots=True);

# %% [markdown]
# -----------------------------------------------------------------
# ### Which one should we use ? (pyplot Vs matplotlib OO method ?)
# - When Plotting something quickly, okay to use pyplot method.
# - When Plotting something more advanced, use the OO method.

# %%
heart_desease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
over_50 = heart_desease[heart_desease["age"] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %% [markdown]
# ### Pyplot method

# %%
over_50.plot(kind="scatter", x="age", y="chol", c="target");

# %% [markdown]
# ---
# ### OO method mixed with Pyplot method

# %%
fig, ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind="scatter", x="age", y="chol", c="target", ax=ax);

# ax.set_xlim([45, 100]); # Set the x-axis view limits.

# %% [markdown]
# ### OO method from scratch
#
# ### axhline()
# - Add a horizontal line spanning the whole or fraction of the Axes.
# ### set()
# - Set multiple properties at once.
# ### suptitle()
# - Add a centered super title to the figure.

# %%
# Set the Style
plt.style.use("seaborn-v0_8-whitegrid")

fig, ax = plt.subplots(figsize=(10, 6))
# Plot the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c = over_50["target"],
                    )
# Customize the Plot
ax.set(title="Heart Disease and Cholesterol Levels",
      xlabel="age",
      ylabel="Cholesterol");

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target");

# Add a Horizontal line
ax.axhline(over_50["chol"].mean(), linestyle="--");

# %% [markdown]
# ### Subplot of chol, age, thalach

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2,
                             ncols=1,
                             figsize=(10, 10),
                              sharex=True) #sharex - share the x ax params.

# Add Data to ax1
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"],
                     cmap="winter")

# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
       ylabel="Cholesterol")
# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")
# Add a meanline
ax0.axhline(y=over_50["chol"].mean(),
           linestyle="--");

# Add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"])
# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate",
       xlabel="Age",
       ylabel="Max Heart Rate");
# Add a legend to ax1
ax1.legend(*scatter.legend_elements(), title="Target")
# Add a meanline
ax1.axhline(y=over_50["thalach"].mean(), linestyle="--");

# Add a title to the figure.
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %% [markdown]
# ---
# ## Customize Plot and Make them Stylish.

# %%
plt.style.available ## list down all available plots
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2026-01-01         4000
# 1   Honda    Red          87899      4   5000 2026-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2026-01-03        16000
# 3     BMW  Black          11179      5  22000 2026-01-04        38000
# 4  Nissan  White         213095      4   3500 2026-01-05        41500
# 5  Toyota  Green          99213      4   4500 2026-01-06        46000
# 6   Honda   Blue          45698      4   7500 2026-01-07        53500
# 7   Honda   Blue          54738      4   7000 2026-01-08        60500
# 8  Toyota  White          60000      4   6250 2026-01-09        66750
# 9  Nissan  White          31600      4   9700 2026-01-10        76450

# %%
car_sales.plot()
# Out:
# <Axes: >

# %%
plt.style.use("seaborn-v0_8-whitegrid") #update this style internallly.

# %%
car_sales.plot()
# Out:
# <Axes: >

# %%
plt.style.use('seaborn-v0_8')

# %%
car_sales.plot()
# Out:
# <Axes: >

# %%
plt.style.use("ggplot")
car_sales.plot()
# Out:
# <Axes: >

# %%
#  Create Dummy Data
data = np.random.rand(10, 4)
data
# Out:
# array([[0.49119464, 0.84893814, 0.97395085, 0.28645954],
#        [0.012398  , 0.08478603, 0.25499609, 0.92006963],
#        [0.4148023 , 0.77479986, 0.89715272, 0.13582109],
#        [0.02538059, 0.48408017, 0.76215733, 0.73161375],
#        [0.92454985, 0.28125878, 0.79470903, 0.44196026],
#        [0.87721205, 0.33134307, 0.60400836, 0.33661134],
#        [0.6897819 , 0.61292851, 0.49137045, 0.98078669],
#        [0.43492698, 0.27442817, 0.86590831, 0.37059483],
#        [0.2824725 , 0.88726086, 0.97742558, 0.65050234],
#        [0.18758497, 0.28751158, 0.66529363, 0.73143973]])

# %%
df = pd.DataFrame(data, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.491195  0.848938  0.973951  0.286460
# 1  0.012398  0.084786  0.254996  0.920070
# 2  0.414802  0.774800  0.897153  0.135821
# 3  0.025381  0.484080  0.762157  0.731614
# 4  0.924550  0.281259  0.794709  0.441960
# 5  0.877212  0.331343  0.604008  0.336611
# 6  0.689782  0.612929  0.491370  0.980787
# 7  0.434927  0.274428  0.865908  0.370595
# 8  0.282472  0.887261  0.977426  0.650502
# 9  0.187585  0.287512  0.665294  0.731440

# %%
ax = df.plot(kind="bar")
ax
# Out:
# <Axes: >

# %% [markdown]
# ---
# ### Customize our Plot with set() method

# %%
ax = df.plot(kind="bar")
# Add some label and title
ax.set(title="Random Number Bar Graph from DataFrame",
      xlabel="Row Number",
      ylabel="Random Number")
# Make the legend visible
ax.legend().set_visible(True)

# %% [markdown]
# ---
# ### Customizing the y and x axis limitations

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2,
                             ncols=1,
                             figsize=(10, 10),
                              sharex=True) #sharex - share the x ax params.

# Add Data to ax1
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"],
                     cmap="winter")

# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
       ylabel="Cholesterol")
# Change the x axis limits
ax0.set_xlim([50, 80])
# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")
# Add a meanline
ax0.axhline(y=over_50["chol"].mean(),
           linestyle="--");

# Add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"],
                     cmap="winter")
# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate",
       xlabel="Age",
       ylabel="Max Heart Rate");

# Change ax1 x axis limits
ax1.set_xlim([50, 80])
ax1.set_xlim([60, 200])
# Add a legend to ax1
ax1.legend(*scatter.legend_elements(), title="Target")
# Add a meanline
ax1.axhline(y=over_50["thalach"].mean(), linestyle="--");

# Add a title to the figure.
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')
